# %% [markdown]
# <a href="https://colab.research.google.com/github/CharviAggarwal02/CODSOFT/blob/main/titanic_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***TITANIC CLASSIFICATION***

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("train.csv",index_col = 'PassengerId')   #NOTE THAT HERE WE ARE USING PASSENGERID AS THE INDEX
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.shape
# Out:
# (891, 11)

# %%
print("Number of rows:",data.shape[0])
print("Number of columns:",data.shape[1])
# Out:
# Number of rows: 891
# Number of columns: 11

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data['Survived'].unique()
# Out:
# array([0, 1])

# %%
data['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['Sex'] = data['Sex'].astype('category')

# %%
data['Survived'] = data['Survived'].astype('category')

# %%
data['Pclass'] = data['Pclass'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    category
#  1   Pclass    891 non-null    category
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    category
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: category(3), float64(2), int64(2), object(4)
# memory usage: 65.6+ KB

# %%
data.describe(include ='all')
# Out:
#         Survived  Pclass                     Name   Sex         Age  \
# count      891.0   891.0                      891   891  714.000000
# unique       2.0     3.0                      891     2         NaN
# top          0.0     3.0  Braund, Mr. Owen Harris  male         NaN
# freq       549.0   491.0                        1   577         NaN
# mean         NaN     NaN                      NaN   NaN   29.699118
# std          NaN     NaN                      NaN   NaN   14.526497
# min          NaN     NaN                      NaN   NaN    0.420000
# 25%          NaN     NaN                      NaN   NaN   20.125000
# 50%          NaN     NaN                      NaN   NaN   28.000000
# 75%          NaN     NaN                      NaN   NaN   38.000000
# max          NaN     NaN                      NaN   NaN   80.000000
#
#              SibSp       Parch  Ticket        Fare    Cabin Embarked
# count   891.000000  891.000000     891  891.000000      204      889
# ...

# %%
sum(data['Sex'] == 'male')
# Out:
# 577

# %%
data[(data['Sex'] == 'male')]
# Out:
#             Survived Pclass                            Name   Sex   Age  \
# PassengerId
# 1                  0      3         Braund, Mr. Owen Harris  male  22.0
# 5                  0      3        Allen, Mr. William Henry  male  35.0
# 6                  0      3                Moran, Mr. James  male   NaN
# 7                  0      1         McCarthy, Mr. Timothy J  male  54.0
# 8                  0      3  Palsson, Master. Gosta Leonard  male   2.0
# ...              ...    ...                             ...   ...   ...
# 884                0      2   Banfield, Mr. Frederick James  male  28.0
# 885                0      3          Sutehall, Mr. Henry Jr  male  25.0
# 887                0      2           Montvila, Rev. Juozas  male  27.0
# 890                1      1           Behr, Mr. Karl Howell  male  26.0
# 891                0      3             Dooley, Mr. Patrick  male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
print("Is there any null or missing values ?",data.isnull().sum().any())
# Out:
# Is there any null or missing values ? True

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data.isnull().sum()/len(data)*100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
data.drop('Cabin',axis =1,inplace =True)

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
data['Embarked'] = data['Embarked'].fillna('S')

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
data.head()
# Out:
#             Survived Pclass  \
# PassengerId
# 1                  0      3
# 2                  1      1
# 3                  1      3
# 4                  1      1
# 5                  0      3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# ...

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(x = 'Survived',data = data)
plt.xlabel('Survival Status')
plt.ylabel('Count')

plt.show()

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot(data = data,x ='Pclass')
plt.show()

# %%
sns.countplot(x='Sex',data = data,palette ='Set2')
plt.title("Male Vs Female Passengers")
plt.show()
# Out:
# <ipython-input-38-40a81d91fc19>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex',data = data,palette ='Set2')

# %%
# Create a histogram with custom styling
plt.figure(figsize=(10, 6))
plt.hist(data['Age'],color ='green',edgecolor='black',label ="Age Distribution")
plt.legend()

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')

#show the plot
plt.show()
